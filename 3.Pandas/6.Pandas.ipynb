# %% [markdown]
# ### Maplotlib / Seaborn

# %% [markdown]
# #### Pandas Opeartions
#
#     Group By
#     Aggregation
#     Join / Merge
#     Pivot Table
#     Graphs

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df1 = pd.read_csv("world-happiness-report-2021.csv")

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 20 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Country name                                149 non-null    object
#  1   Regional indicator                          149 non-null    object
#  2   Ladder score                                149 non-null    float64
#  3   Standard error of ladder score              149 non-null    float64
#  4   upperwhisker                                149 non-null    float64
#  5   lowerwhisker                                149 non-null    float64
#  6   Logged GDP per capita                       149 non-null    float64
#  7   Social support                              149 non-null    float64
#  8   Healthy life expectancy                     149 non-null    float64
# ...

# %%
df2 = pd.read_csv('world-happiness-report.csv')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1949 entries, 0 to 1948
# Data columns (total 11 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Country name                      1949 non-null   object
#  1   year                              1949 non-null   int64
#  2   Life Ladder                       1949 non-null   float64
#  3   Log GDP per capita                1913 non-null   float64
#  4   Social support                    1936 non-null   float64
#  5   Healthy life expectancy at birth  1894 non-null   float64
#  6   Freedom to make life choices      1917 non-null   float64
#  7   Generosity                        1860 non-null   float64
#  8   Perceptions of corruption         1839 non-null   float64
#  9   Positive affect                   1927 non-null   float64
#  10  Negative affect                   1933 non-null   float64
# dtypes: float64(9), int64(1), object(1)
# ...

# %%
df1.head()
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe         7.842
# 1      Denmark     Western Europe         7.620
# 2  Switzerland     Western Europe         7.571
# 3      Iceland     Western Europe         7.554
# 4  Netherlands     Western Europe         7.464
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                           0.032         7.904         7.780
# 1                           0.035         7.687         7.552
# 2                           0.036         7.643         7.500
# 3                           0.059         7.670         7.438
# 4                           0.027         7.518         7.410
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0                 10.775           0.954                     72.0
# 1                 10.933           0.954                     72.7
# 2                 11.117           0.942                     74.4
# ...

# %%
df2.head()
# Out:
#   Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0  Afghanistan  2008        3.724               7.370           0.451
# 1  Afghanistan  2009        4.402               7.540           0.552
# 2  Afghanistan  2010        4.758               7.647           0.539
# 3  Afghanistan  2011        3.832               7.620           0.521
# 4  Afghanistan  2012        3.783               7.705           0.521
#
#    Healthy life expectancy at birth  Freedom to make life choices  Generosity  \
# 0                             50.80                         0.718       0.168
# 1                             51.20                         0.679       0.190
# 2                             51.60                         0.600       0.121
# 3                             51.92                         0.496       0.162
# 4                             52.24                         0.531       0.236
#
#    Perceptions of corruption  Positive affect  Negative affect
# ...

# %%
df = pd.DataFrame({
    'height': np.random.normal(140, 20, 100),
    'weight': np.random.normal(65, 20, 100),
    'salary': np.random.uniform(30, 80, 100),
    'country': pd.Categorical(np.random.choice(['India', 'USA', 'AUS', 'NZ', 'UK'], 100, replace=True)),
    'sex': pd.Categorical(np.random.choice(['Male', 'Female'], 100, replace=True))
}
)

# %%
df.head(10)
# Out:
#        height      weight     salary country     sex
# 0  132.758511   77.954238  62.335326   India    Male
# 1  150.688877   61.547787  71.385235      UK  Female
# 2  170.429607  101.416831  34.709765     USA  Female
# 3  147.637687   47.097126  52.854985      UK  Female
# 4  142.770677   74.690871  30.422350      NZ    Male
# 5   98.093778   97.836998  56.887265     USA  Female
# 6  158.422848   97.671456  38.561890     USA    Male
# 7  134.120273   65.300680  51.868670   India  Female
# 8  145.493694   75.431598  65.737376     AUS    Male
# 9  143.127183   24.775250  62.823177     AUS    Male

# %% [markdown]
# #### unique

# %%
df['country'].unique()
# Out:
# [India, UK, USA, NZ, AUS]
# Categories (5, object): [India, UK, USA, NZ, AUS]

# %%
df['sex'].unique()
# Out:
# [Male, Female]
# Categories (2, object): [Male, Female]

# %% [markdown]
# #### value_counts

# %%
df['country'].value_counts()
# Out:
# UK       28
# NZ       25
# India    17
# USA      16
# AUS      14
# Name: country, dtype: int64

# %%
(df['country'].value_counts()/100) * 100
# Out:
# UK       28.0
# NZ       25.0
# India    17.0
# USA      16.0
# AUS      14.0
# Name: country, dtype: float64

# %%
((df['country'].value_counts()/100) * 100).plot(kind='bar')

# %%
((df['country'].value_counts()/100) * 100).plot(kind='pie')

# %%
df['sex'].value_counts()
# Out:
# Male      50
# Female    50
# Name: sex, dtype: int64

# %% [markdown]
# #### Group By

# %%
lz = df.groupby('sex')

# %%
lz.groups
# Out:
# {'Female': Int64Index([ 1,  2,  3,  5,  7, 10, 14, 15, 17, 19, 20, 21, 22, 24, 27, 29, 30,
#              32, 33, 34, 35, 37, 41, 43, 45, 46, 47, 54, 55, 56, 57, 59, 61, 62,
#              63, 65, 67, 70, 72, 73, 75, 77, 80, 84, 90, 92, 94, 95, 97, 98],
#             dtype='int64'),
#  'Male': Int64Index([ 0,  4,  6,  8,  9, 11, 12, 13, 16, 18, 23, 25, 26, 28, 31, 36, 38,
#              39, 40, 42, 44, 48, 49, 50, 51, 52, 53, 58, 60, 64, 66, 68, 69, 71,
#              74, 76, 78, 79, 81, 82, 83, 85, 86, 87, 88, 89, 91, 93, 96, 99],
#             dtype='int64')}

# %%
dfs = []
for key, value in lz.groups.items():
    print(key)
    dfs.append(df.loc[value])
# Out:
# Female
# Male

# %%
Female, Male = dfs

# %%
Male.head()
# Out:
#        height     weight     salary country   sex
# 0  132.758511  77.954238  62.335326   India  Male
# 4  142.770677  74.690871  30.422350      NZ  Male
# 6  158.422848  97.671456  38.561890     USA  Male
# 8  145.493694  75.431598  65.737376     AUS  Male
# 9  143.127183  24.775250  62.823177     AUS  Male

# %%
Female.head()
# Out:
#        height      weight     salary country     sex
# 1  150.688877   61.547787  71.385235      UK  Female
# 2  170.429607  101.416831  34.709765     USA  Female
# 3  147.637687   47.097126  52.854985      UK  Female
# 5   98.093778   97.836998  56.887265     USA  Female
# 7  134.120273   65.300680  51.868670   India  Female

# %%
len(df2['Country name'].unique())
# Out:
# 166

# %%
india = df2[df2['Country name'] == 'India']

# %%
india
# Out:
#     Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 732        India  2006        5.348               8.145           0.707
# 733        India  2007        5.027               8.204           0.569
# 734        India  2008        5.146               8.220           0.684
# 735        India  2009        4.522               8.281           0.653
# 736        India  2010        4.989               8.349           0.605
# 737        India  2011        4.635               8.387           0.553
# 738        India  2012        4.720               8.428           0.511
# 739        India  2013        4.428               8.478           0.553
# 740        India  2014        4.424               8.538           0.621
# 741        India  2015        4.342               8.604           0.610
# 742        India  2016        4.179               8.673           0.614
# 743        India  2017        4.046               8.730           0.607
# ...

# %%
df2.columns
# Out:
# Index(['Country name', 'year', 'Life Ladder', 'Log GDP per capita',
#        'Social support', 'Healthy life expectancy at birth',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Positive affect', 'Negative affect'],
#       dtype='object')

# %%
india.plot(x='year', y='Life Ladder')

# %%
india.plot(x='year', y='Log GDP per capita')

# %%
df2.columns
# Out:
# Index(['Country name', 'year', 'Life Ladder', 'Log GDP per capita',
#        'Social support', 'Healthy life expectancy at birth',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Positive affect', 'Negative affect'],
#       dtype='object')

# %%
import os
os.mkdir('GDP_Image')

# %% [raw]
# for key, value in df2.groupby('Country name').groups.items():
#     plt.figure(dpi=150)
#     plt.title(key)
#     d = df2.loc[value]
#     x = d['year']
#     y = d['Log GDP per capita']
#     plt.plot(x, y, 'r--o', label=key)
#     plt.grid()
#     plt.legend()
#     plt.tight_layout()
#     plt.savefig(f"GDP_Image/{key}.jpeg", dpi=200)
#     #plt.show()

# %% [markdown]
#     df.groupby('column').aggregation_function()

# %%
df.groupby('sex').mean()
# Out:
#             height     weight     salary
# sex
# Female  133.611967  69.976099  53.846393
# Male    139.850970  63.166038  55.641784

# %%
df.groupby('sex').mean()
# Out:
#             height     weight     salary
# sex
# Female  133.611967  69.976099  53.846393
# Male    139.850970  63.166038  55.641784

# %%
df['sex'].value_counts()
# Out:
# Male      50
# Female    50
# Name: sex, dtype: int64

# %%
df.groupby('sex')['country'].count()
# Out:
# sex
# Female    50
# Male      50
# Name: country, dtype: int64

# %%
df.groupby('sex').describe().T
# Out:
# sex               Female        Male
# height count   50.000000   50.000000
#        mean   133.611967  139.850970
#        std     18.124276   17.385262
#        min     98.093778  105.858503
#        25%    120.935793  125.970799
#        50%    132.589167  142.764615
#        75%    145.600432  150.995127
#        max    170.731761  196.205544
# weight count   50.000000   50.000000
#        mean    69.976099   63.166038
#        std     15.869870   20.263784
#        min     30.512695    6.694392
#        25%     58.261715   52.284698
#        50%     70.034616   64.602181
#        75%     80.060692   77.884792
#        max    105.698041   97.671456
# salary count   50.000000   50.000000
#        mean    53.846393   55.641784
#        std     15.082586   15.729731
#        min     30.775914   30.422350
#        25%     40.447950   42.214411
#        50%     54.269072   54.413286
#        75%     65.068798   68.990994
#        max     79.612524   79.985563

# %%
df.groupby('sex')['height'].describe().T
# Out:
# sex        Female        Male
# count   50.000000   50.000000
# mean   133.611967  139.850970
# std     18.124276   17.385262
# min     98.093778  105.858503
# 25%    120.935793  125.970799
# 50%    132.589167  142.764615
# 75%    145.600432  150.995127
# max    170.731761  196.205544

# %% [markdown]
#     df.agg
#     df.aggregate

# %%
df.groupby('sex').agg({
    'height': [ 'mean', 'median'],
    'weight': [ 'mean', 'std'],
    'salary': [ 'median', 'min', 'max'],
    'country': [ 'count']
    
}).T
# Out:
# sex                 Female        Male
# height  mean    133.611967  139.850970
#         median  132.589167  142.764615
# weight  mean     69.976099   63.166038
#         std      15.869870   20.263784
# salary  median   54.269072   54.413286
#         min      30.775914   30.422350
#         max      79.612524   79.985563
# country count    50.000000   50.000000

# %% [markdown]
# ### Pivot Tables

# %%
df.head()
# Out:
#        height      weight     salary country     sex
# 0  132.758511   77.954238  62.335326   India    Male
# 1  150.688877   61.547787  71.385235      UK  Female
# 2  170.429607  101.416831  34.709765     USA  Female
# 3  147.637687   47.097126  52.854985      UK  Female
# 4  142.770677   74.690871  30.422350      NZ    Male

# %%
df.pivot_table(values='height', index='sex', columns='country', aggfunc='mean').T
# Out:
# sex          Female        Male
# country
# AUS      129.226956  145.370756
# India    128.623840  136.300113
# NZ       123.766403  138.763819
# UK       140.492600  134.351649
# USA      140.849806  146.296830

# %%
df.groupby(['country', 'sex'])[['height']].mean().unstack()
# Out:
#              height
# sex          Female        Male
# country
# AUS      129.226956  145.370756
# India    128.623840  136.300113
# NZ       123.766403  138.763819
# UK       140.492600  134.351649
# USA      140.849806  146.296830

# %%
import seaborn as sns

# %%
flights = sns.load_dataset('flights')

# %%
flights.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   year        144 non-null    int64
#  1   month       144 non-null    category
#  2   passengers  144 non-null    int64
# dtypes: category(1), int64(2)
# memory usage: 2.9 KB

# %%
flights.head() # Long
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
flights.pivot_table(index='month', columns='year', values='passengers') # long to wide conversion
# Out:
# year       1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  \
# month
# January     112   115   145   171   196   204   242   284   315   340   360
# February    118   126   150   180   196   188   233   277   301   318   342
# March       132   141   178   193   236   235   267   317   356   362   406
# April       129   135   163   181   235   227   269   313   348   348   396
# May         121   125   172   183   229   234   270   318   355   363   420
# June        135   149   178   218   243   264   315   374   422   435   472
# July        148   170   199   230   264   302   364   413   465   491   548
# August      148   170   199   242   272   293   347   405   467   505   559
# September   136   158   184   209   237   259   312   355   404   404   463
# October     119   133   162   191   211   229   274   306   347   359   407
# November    104   114   146   172   180   203   237   271   305   310   362
# ...

# %%
plt.figure(dpi=100)
sns.heatmap(flights.pivot_table(index='month', columns='year', values='passengers'), cmap='rainbow')
plt.show()

# %%
df.head()
# Out:
#        height      weight     salary country     sex
# 0  132.758511   77.954238  62.335326   India    Male
# 1  150.688877   61.547787  71.385235      UK  Female
# 2  170.429607  101.416831  34.709765     USA  Female
# 3  147.637687   47.097126  52.854985      UK  Female
# 4  142.770677   74.690871  30.422350      NZ    Male

# %% [markdown]
# ## How to Save Data

# %%
df.to_csv("salary_data.csv", index=False)

# %%
# !head salary_data.csv
# Out:
# height,weight,salary,country,sex
# 132.75851136839316,77.95423822396707,62.33532584070673,India,Male
# 150.688876898226,61.54778715342611,71.38523503444935,UK,Female
# 170.4296065672375,101.41683130823145,34.709765046407746,USA,Female
# 147.63768730664555,47.097126167065774,52.854985332025855,UK,Female
# 142.7706767369015,74.69087074395252,30.42234961346556,NZ,Male
# 98.0937782694023,97.83699754938144,56.88726503585946,USA,Female
# 158.42284781931673,97.67145599724132,38.56188951311395,USA,Male
# 134.12027289315407,65.30067984431092,51.86867013545984,India,Female
# 145.49369421540993,75.43159824920389,65.7373761152648,AUS,Male

# %%
d = pd.read_csv('salary_data.csv')
d.head()
# Out:
#        height      weight     salary country     sex
# 0  132.758511   77.954238  62.335326   India    Male
# 1  150.688877   61.547787  71.385235      UK  Female
# 2  170.429607  101.416831  34.709765     USA  Female
# 3  147.637687   47.097126  52.854985      UK  Female
# 4  142.770677   74.690871  30.422350      NZ    Male

# %%
df['id'] = np.arange(1, df.shape[0]+1)

# %%
df
# Out:
#         height      weight     salary country     sex   id
# 0   132.758511   77.954238  62.335326   India    Male    1
# 1   150.688877   61.547787  71.385235      UK  Female    2
# 2   170.429607  101.416831  34.709765     USA  Female    3
# 3   147.637687   47.097126  52.854985      UK  Female    4
# 4   142.770677   74.690871  30.422350      NZ    Male    5
# ..         ...         ...        ...     ...     ...  ...
# 95  141.146521   72.481908  64.687305     AUS  Female   96
# 96  144.883046   89.605664  37.494134   India    Male   97
# 97  116.038653   85.260310  75.481158      NZ  Female   98
# 98  139.357109   51.072973  31.268102      UK  Female   99
# 99  123.703176   90.039500  63.357786     USA    Male  100
#
# [100 rows x 6 columns]

# %%
df1 = df[['id', 'height', 'weight', 'salary']]

# %%
df1.head()
# Out:
#    id      height      weight     salary
# 0   1  132.758511   77.954238  62.335326
# 1   2  150.688877   61.547787  71.385235
# 2   3  170.429607  101.416831  34.709765
# 3   4  147.637687   47.097126  52.854985
# 4   5  142.770677   74.690871  30.422350

# %%
df2 = df[['id', 'country', 'sex']]

# %%
df1.head()
# Out:
#    id      height      weight     salary
# 0   1  132.758511   77.954238  62.335326
# 1   2  150.688877   61.547787  71.385235
# 2   3  170.429607  101.416831  34.709765
# 3   4  147.637687   47.097126  52.854985
# 4   5  142.770677   74.690871  30.422350

# %%
df2.head()
# Out:
#    id country     sex
# 0   1   India    Male
# 1   2      UK  Female
# 2   3     USA  Female
# 3   4      UK  Female
# 4   5      NZ    Male

# %%
dff1 = df1[:10]

# %%
dff2 = df2[:20:2]

# %%
dff1
# Out:
#    id      height      weight     salary
# 0   1  132.758511   77.954238  62.335326
# 1   2  150.688877   61.547787  71.385235
# 2   3  170.429607  101.416831  34.709765
# 3   4  147.637687   47.097126  52.854985
# 4   5  142.770677   74.690871  30.422350
# 5   6   98.093778   97.836998  56.887265
# 6   7  158.422848   97.671456  38.561890
# 7   8  134.120273   65.300680  51.868670
# 8   9  145.493694   75.431598  65.737376
# 9  10  143.127183   24.775250  62.823177

# %%
dff2
# Out:
#     id country     sex
# 0    1   India    Male
# 2    3     USA  Female
# 4    5      NZ    Male
# 6    7     USA    Male
# 8    9     AUS    Male
# 10  11     AUS  Female
# 12  13     USA    Male
# 14  15      UK  Female
# 16  17      NZ    Male
# 18  19     AUS    Male

# %%
dff3 = dff1.merge(dff2, how='inner', on='id')
dff3
# Out:
#    id      height      weight     salary country     sex
# 0   1  132.758511   77.954238  62.335326   India    Male
# 1   3  170.429607  101.416831  34.709765     USA  Female
# 2   5  142.770677   74.690871  30.422350      NZ    Male
# 3   7  158.422848   97.671456  38.561890     USA    Male
# 4   9  145.493694   75.431598  65.737376     AUS    Male

# %%
dff3 = dff1.merge(dff2, how='left', on='id')
dff3
# Out:
#    id      height      weight     salary country     sex
# 0   1  132.758511   77.954238  62.335326   India    Male
# 1   2  150.688877   61.547787  71.385235     NaN     NaN
# 2   3  170.429607  101.416831  34.709765     USA  Female
# 3   4  147.637687   47.097126  52.854985     NaN     NaN
# 4   5  142.770677   74.690871  30.422350      NZ    Male
# 5   6   98.093778   97.836998  56.887265     NaN     NaN
# 6   7  158.422848   97.671456  38.561890     USA    Male
# 7   8  134.120273   65.300680  51.868670     NaN     NaN
# 8   9  145.493694   75.431598  65.737376     AUS    Male
# 9  10  143.127183   24.775250  62.823177     NaN     NaN

# %%
dff3 = dff1.merge(dff2, how='right', on='id')
dff3
# Out:
#    id      height      weight     salary country     sex
# 0   1  132.758511   77.954238  62.335326   India    Male
# 1   3  170.429607  101.416831  34.709765     USA  Female
# 2   5  142.770677   74.690871  30.422350      NZ    Male
# 3   7  158.422848   97.671456  38.561890     USA    Male
# 4   9  145.493694   75.431598  65.737376     AUS    Male
# 5  11         NaN         NaN        NaN     AUS  Female
# 6  13         NaN         NaN        NaN     USA    Male
# 7  15         NaN         NaN        NaN      UK  Female
# 8  17         NaN         NaN        NaN      NZ    Male
# 9  19         NaN         NaN        NaN     AUS    Male

# %%
dff3 = dff1.merge(dff2, how='outer', on='id')
dff3
# Out:
#     id      height      weight     salary country     sex
# 0    1  132.758511   77.954238  62.335326   India    Male
# 1    2  150.688877   61.547787  71.385235     NaN     NaN
# 2    3  170.429607  101.416831  34.709765     USA  Female
# 3    4  147.637687   47.097126  52.854985     NaN     NaN
# 4    5  142.770677   74.690871  30.422350      NZ    Male
# 5    6   98.093778   97.836998  56.887265     NaN     NaN
# 6    7  158.422848   97.671456  38.561890     USA    Male
# 7    8  134.120273   65.300680  51.868670     NaN     NaN
# 8    9  145.493694   75.431598  65.737376     AUS    Male
# 9   10  143.127183   24.775250  62.823177     NaN     NaN
# 10  11         NaN         NaN        NaN     AUS  Female
# 11  13         NaN         NaN        NaN     USA    Male
# 12  15         NaN         NaN        NaN      UK  Female
# 13  17         NaN         NaN        NaN      NZ    Male
# 14  19         NaN         NaN        NaN     AUS    Male

# %% [markdown]
# ##### Assignments

# %% [markdown]
#     Monday
